# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'euclidean-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['manhattan', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("manhattan", "TopDom"),("manhattan", "IS"), ("manhattan", "HiCseg"), ("manhattan", "IC_Finder"), ("manhattan", "clusterTAD"), ("manhattan", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# manhattan v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.199e-05 U_stat=4.320e+02
# manhattan v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.940e+02
# manhattan v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.636e-08 U_stat=4.840e+02
# manhattan v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.203e-07 U_stat=4.670e+02
# manhattan v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.436e-03 U_stat=3.990e+02
# manhattan v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.904e-05 U_stat=4.410e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'euclidean-FMS'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['manhattan', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("manhattan", "TopDom"),("manhattan", "IS"), ("manhattan", "HiCseg"), ("manhattan", "IC_Finder"), ("manhattan", "clusterTAD"), ("manhattan", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# manhattan v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.225e-04 U_stat=4.240e+02
# manhattan v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.860e+02
# manhattan v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.899e-07 U_stat=4.750e+02
# manhattan v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.362e-06 U_stat=4.630e+02
# manhattan v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.659e-02 U_stat=3.700e+02
# manhattan v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.314e-02 U_stat=3.730e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'manhattan-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['euclidean', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("euclidean", "TopDom"),("euclidean", "IS"), ("euclidean", "HiCseg"), ("euclidean", "IC_Finder"), ("euclidean", "clusterTAD"), ("euclidean", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# euclidean v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.165e-01 U_stat=3.060e+02
# euclidean v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.062e-04 U_stat=7.400e+01
# euclidean v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.636e-08 U_stat=4.840e+02
# euclidean v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.344e-05 U_stat=4.360e+02
# euclidean v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.950e+02
# euclidean v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.330e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'manhattan-FMS'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['euclidean', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("euclidean", "TopDom"),("euclidean", "IS"), ("euclidean", "HiCseg"), ("euclidean", "IC_Finder"), ("euclidean", "clusterTAD"), ("euclidean", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# euclidean v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.990e+02
# euclidean v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.198e-05 U_stat=5.500e+01
# euclidean v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.737e-05 U_stat=4.350e+02
# euclidean v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.193e-03 U_stat=4.010e+02
# euclidean v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.640e+02
# euclidean v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=1.970e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'chebyshev-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['euclidean', 'manhattan', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("euclidean", "TopDom"),("euclidean", "IS"), ("euclidean", "HiCseg"), ("euclidean", "IC_Finder"), ("euclidean", "clusterTAD"), ("euclidean", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# euclidean v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.389e-05 U_stat=4.390e+02
# euclidean v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.308e-07 U_stat=4.740e+02
# euclidean v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.636e-08 U_stat=4.840e+02
# euclidean v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.201e-05 U_stat=4.450e+02
# euclidean v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.217e-07 U_stat=4.680e+02
# euclidean v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.487e-07 U_stat=4.800e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'chebyshev-FMS'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['euclidean', 'manhattan', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("euclidean", "TopDom"),("euclidean", "IS"), ("euclidean", "HiCseg"), ("euclidean", "IC_Finder"), ("euclidean", "clusterTAD"), ("euclidean", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity-pvalue.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# euclidean v.s. TopDom: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.320e-07 U_stat=4.660e+02
# euclidean v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.820e-01 U_stat=1.670e+02
# euclidean v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.636e-08 U_stat=4.840e+02
# euclidean v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.135e-07 U_stat=4.820e+02
# euclidean v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.573e-03 U_stat=3.980e+02
# euclidean v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.258e-03 U_stat=3.940e+02
