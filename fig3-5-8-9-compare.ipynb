# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =4
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN/SimulationData/TAD_results/compare/tadquality.txt")
print(eval)
CASPAIN=np.array(eval[:1]).flatten()
ClusterTAD=np.array(eval[1:2]).flatten()
ICFinder=np.array(eval[2:3]).flatten()
TopDom=np.array(eval[3:4]).flatten()
HiCseg=np.array(eval[4:5]).flatten()
IS=np.array(eval[5:6]).flatten()
print(IS)
total_width, n = 0.8,6
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x,CASPAIN,width=width, label='CASPAIN',color='#e31a1c')
plt.bar(x+width,ClusterTAD,width=width, label='ClusterTAD',color='#5BB7CE')
plt.bar(x+2*width,ICFinder,width=width, label='IC-Finder',color='#b2df8a')
plt.bar(x+3*width,TopDom,width=width, label='TopDom',color='#7572B5')
plt.bar(x+4*width,HiCseg,width=width, label='HiCseg',color='#fb9a99')
plt.bar(x+5*width,IS,width=width, label='IS',color='#CAB47B')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN/SimulationData/TAD_results/compare/evaslute.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[ 0.98   0.917  0.881  0.988]
#  [ 0.916  0.58   0.351  0.953]
#  [ 0.72   0.285  0.255  0.823]
#  [ 0.976  0.904  0.849  0.986]
#  [ 0.661  0.222  0.375  0.781]
#  [ 0.808 -0.037  0.006  0.894]]
# [ 0.808 -0.037  0.006  0.894]

# %%
#Figure3:comparion on simulated data
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =2
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN/TAD_results/simulated_differentNoise_tadResults/16noise-quality-compare-trueTAD-RI-FMS.txt")
print(eval)
CASPAIN_euclidean=np.array(eval[:1]).flatten()
CASPAIN_manhattan=np.array(eval[1:2]).flatten()
CASPAIN_chebyshev=np.array(eval[2:3]).flatten()
TopDom=np.array(eval[3:4]).flatten()
IS=np.array(eval[4:5]).flatten()
HiCseg=np.array(eval[5:6]).flatten()
IC_Finder=np.array(eval[6:7]).flatten()
clusterTAD=np.array(eval[7:8]).flatten()
print(IS)
total_width, n = 0.8,8
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x,CASPAIN_euclidean,width=width, label='CASPAIN_euclidean')
plt.bar(x+width,CASPAIN_manhattan,width=width, label='CASPAIN_manhattan')
plt.bar(x+2*width,CASPAIN_chebyshev,width=width, label='CASPAIN_chebyshev')
plt.bar(x+3*width,TopDom,width=width, label='TopDom')
plt.bar(x+4*width,IS,width=width, label='IS')
plt.bar(x+5*width,HiCseg,width=width, label='HiCseg')
plt.bar(x+6*width,IC_Finder,width=width, label='IC_Finder')
plt.bar(x+7*width,clusterTAD,width=width, label='clusterTAD')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN/TAD_results/simulated_differentNoise_tadResults/16noise_evaslute.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[0.92 0.95]
#  [0.58 0.72]
#  [0.41 0.57]
#  [0.95 0.97]
#  [0.73 0.84]
#  [0.56 0.7 ]
#  [0.77 0.86]
#  [0.82 0.9 ]]
# [0.73 0.84]

# %%
#Figure5:
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =3
x = np.arange(size)
eval=np.loadtxt("/data2/ghy_data/ghy_data/GM12878/50kb/smc3-normalize-methods-compare.txt")
print(eval)
CASPAIN_euclidean=np.array(eval[:1]).flatten()
CASPAIN_manhattan=np.array(eval[1:2]).flatten()
CASPAIN_chebyshev=np.array(eval[2:3]).flatten()

print(CASPAIN_euclidean)
total_width, n = 0.8,3
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x,CASPAIN_euclidean,width=width, label='CASPAIN_euclidean')
plt.bar(x+width,CASPAIN_manhattan,width=width, label='CASPAIN_manhattan')
plt.bar(x+2*width,CASPAIN_chebyshev,width=width, label='CASPAIN_chebyshev')

plt.legend()
plt.savefig('/data2/ghy_data/ghy_data/GM12878/50kb/50kb-smc3-normalize-methods-compare.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[0.451 0.458 0.456]
#  [0.358 0.474 0.421]
#  [0.386 0.253 0.369]]
# [0.451 0.458 0.456]

# %%
#Figure8
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =1
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/H3K4me1-methods-compare.txt")
print(eval)
CASPAIN_euclidean=np.array(eval[:1]).flatten()
CASPAIN_chebyshev=np.array(eval[1:2]).flatten()
CASPAIN_manhattan=np.array(eval[2:3]).flatten()
clusterTAD=np.array(eval[3:4]).flatten()
HiCseg=np.array(eval[4:5]).flatten()
IC_Finder=np.array(eval[5:6]).flatten()
IS=np.array(eval[6:7]).flatten()
TopDom=np.array(eval[7:8]).flatten()
DI=np.array(eval[8:9]).flatten()
print(IS)
total_width, n = 0.9,9
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x,CASPAIN_euclidean,width=width, label='CASPAIN_euclidean')
plt.bar(x+width,CASPAIN_manhattan,width=width, label='CASPAIN_manhattan')
plt.bar(x+2*width,CASPAIN_chebyshev,width=width, label='CASPAIN_chebyshev')
plt.bar(x+3*width,TopDom,width=width, label='TopDom')
plt.bar(x+4*width,IS,width=width, label='IS')
plt.bar(x+5*width,HiCseg,width=width, label='HiCseg')
plt.bar(x+6*width,IC_Finder,width=width, label='IC_Finder')
plt.bar(x+7*width,clusterTAD,width=width, label='clusterTAD')
plt.bar(x+8*width,DI,width=width, label='DI')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/H3K4me1-methods-compare.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [0.444 0.373 0.407 0.353 0.302 0.454 0.434 0.409 0.448]
# [0.434]

# %%
#Figure8b:TAD length
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =1
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/tadLength/TADLength-methods-comapre.txt")
print(eval)
CASPAIN_euclidean=np.array(eval[:1]).flatten()
CASPAIN_manhattan=np.array(eval[1:2]).flatten()
CASPAIN_chebyshev=np.array(eval[2:3]).flatten()
TopDom=np.array(eval[3:4]).flatten()
IS=np.array(eval[4:5]).flatten()
HiCseg=np.array(eval[5:6]).flatten()
IC_Finder=np.array(eval[6:7]).flatten()
clusterTAD=np.array(eval[7:8]).flatten()
DI=np.array(eval[8:9]).flatten()
print(IS)
total_width, n = 0.9,9
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x,CASPAIN_euclidean,width=width, label='CASPAIN_euclidean')
plt.bar(x+width,CASPAIN_manhattan,width=width, label='CASPAIN_manhattan')
plt.bar(x+2*width,CASPAIN_chebyshev,width=width, label='CASPAIN_chebyshev')
plt.bar(x+3*width,TopDom,width=width, label='TopDom')
plt.bar(x+4*width,IS,width=width, label='IS')
plt.bar(x+5*width,HiCseg,width=width, label='HiCseg')
plt.bar(x+6*width,IC_Finder,width=width, label='IC_Finder')
plt.bar(x+7*width,clusterTAD,width=width, label='clusterTAD')
plt.bar(x+8*width,DI,width=width, label='DI')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADLength-methods-comapre.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [ 815458. 2127314.  387387.  523396.   50000.   94914.  336646. 1686107.
#   783750.]
# [50000.]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import pandas as pd
mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
name = 'euclidean-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,whis=2.5)
sns.stripplot(data = dat)
line.set_title(name)
plt.savefig(dir+'/'+name+'-similarity.pdf',pad_inches=0,bbox_inches='tight')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'euclidean-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['manhattan', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("manhattan", "IS"), ("manhattan", "HiCseg"), ("manhattan", "IC_Finder"), ("manhattan", "clusterTAD"), ("manhattan", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity.pdf',pad_inches=0,bbox_inches='tight')
plt.show()
# Out:
# manhattan v.s. IS: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=2.940e+02
# manhattan v.s. HiCseg: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.197e-08 U_stat=4.840e+02
# manhattan v.s. IC_Finder: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.836e-07 U_stat=4.670e+02
# manhattan v.s. clusterTAD: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.196e-03 U_stat=3.990e+02
# manhattan v.s. DI: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.586e-05 U_stat=4.410e+02

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from statannot import add_stat_annotation

import matplotlib as mpl

mpl.rcParams['font.size'] = 10
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
sns.set(style="ticks")
name = 'euclidean-RI'

dir="/home/ghaiyan/project/CASPIAN-git/TAD_results/GM2878/50kb/TADs_similarity"
dat = pd.read_excel(dir+"/tadSimilarity.xlsx", sheet_name=name)
order=['manhattan', 'chebyshev', 'TopDom', 'IS','HiCseg','IC_Finder','clusterTAD','DI']
plt.figure(figsize=(8,4))
line = sns.boxplot(data = dat,  whis=2.5)
sns.stripplot(data = dat)

line, test_results = add_stat_annotation(line, data=dat, order=order,
                                   box_pairs=[("manhattan", "IS"), ("manhattan", "HiCseg"), ("manhattan", "IC_Finder"), ("manhattan", "clusterTAD"), ("manhattan", "DI")],
                                   test='Mann-Whitney', text_format='full', loc='inside', verbose=2)
plt.savefig(dir+'/'+name+'-similarity.pdf',pad_inches=0,bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =6
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN/SimulationData/TAD_results/compare/tq2.txt")
print(eval)
avgTAD=np.array(eval[:1]).flatten()
tadquality=np.array(eval[1:2]).flatten()
CHI=np.array(eval[2:3]).flatten()
print(avgTAD)
print(tadquality)
print(CHI)
fig, ax = plt.subplots()
plt.bar(x, CHI)
plt.xticks(x, ('CASPAIN', 'ClusterTAD', 'IC-Finder', 'TopDom','HiCseg','IS'))
plt.savefig('/home/ghaiyan/project/CASPIAN/SimulationData/TAD_results/compare/CHI.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[ 5.5000e+00  8.0700e+01 -4.1750e+01 -1.3430e+01 -7.7470e+01  1.1299e+02]
#  [-3.9600e-01 -4.8710e+00 -1.7000e-01  5.7000e-02  1.6500e-01 -5.3390e+00]
#  [ 1.2000e-01 -2.7160e+00 -7.3050e+00 -2.9350e+00 -1.3010e+01 -8.9540e+00]]
# [  5.5   80.7  -41.75 -13.43 -77.47 112.99]
# [-0.396 -4.871 -0.17   0.057  0.165 -5.339]
# [  0.12   -2.716  -7.305  -2.935 -13.01   -8.954]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =4
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN/TAD_results/GM2878/chr19/50kb/eval-achor-matrix")
print(eval)
CASPAIN=np.array(eval[:1]).flatten()
IS=np.array(eval[1:2]).flatten()
TopDom=np.array(eval[2:3]).flatten()
ClusterTAD=np.array(eval[3:4]).flatten()
HiCseg=np.array(eval[4:5]).flatten()
ICFinder=np.array(eval[5:6]).flatten()

total_width, n = 0.8,6
width = total_width / n
x = x - (total_width - width) / 2
#plt.axes(yscale = "log")
plt.bar(x,CASPAIN,width=width, label='CASPAIN')
plt.bar(x+width,IS,width=width, label='IS')
plt.bar(x+2*width,TopDom,width=width, label='TopDom')
plt.bar(x+3*width,ClusterTAD,width=width, label='ClusterTAD')
plt.bar(x+4*width,HiCseg,width=width, label='HiCseg')
plt.bar(x+5*width,ICFinder,width=width, label='IC-Finder')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN/TAD_results/GM2878/chr19/50kb/eval-achor.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[0.8   0.733 0.682 0.733]
#  [0.667 0.608 0.5   0.56 ]
#  [0.692 0.673 0.561 0.589]
#  [0.757 0.73  0.622 0.73 ]
#  [0.675 0.632 0.5   0.55 ]
#  [0.614 0.505 0.494 0.505]
#  [0.707 0.657 0.565 0.612]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42
import numpy as np
size =4
x = np.arange(size)
eval=np.loadtxt("/home/ghaiyan/project/CASPIAN/evaluate_TADS/GM12878/chr19_5kb/TAD/compare/anchor-plot.txt")
print(eval)
CASPAIN=np.array(eval[:1]).flatten()
TopDom=np.array(eval[1:2]).flatten()
HiCseg=np.array(eval[2:3]).flatten()
ClusterTAD=np.array(eval[3:4]).flatten()
ICFinder=np.array(eval[4:5]).flatten()


total_width, n = 0.8,5
width = total_width / n
x = x - (total_width - width) / 2
#plt.axes(yscale = "log")
plt.bar(x,CASPAIN,width=width, label='CASPAIN')
plt.bar(x+width,TopDom,width=width, label='TopDom')
plt.bar(x+2*width,HiCseg,width=width, label='HiCseg')
plt.bar(x+3*width,ClusterTAD,width=width, label='ClusterTAD')
plt.bar(x+4*width,ICFinder,width=width, label='IC-Finder')
plt.legend()
plt.savefig('/home/ghaiyan/project/CASPIAN/evaluate_TADS/GM12878/chr19_5kb/TAD/compare/anchor-plot.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# [[0.75 0.67 0.58 0.62]
#  [0.72 0.63 0.55 0.58]
#  [0.6  0.51 0.47 0.48]
#  [0.72 0.63 0.54 0.54]
#  [0.66 0.62 0.54 0.57]]
